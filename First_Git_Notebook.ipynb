# %%
df=spark.read.format('csv').option('header',True).option('InferSchema',True).load('/Volumes/datamodeling/bronze/practice_read_write_demo/Order.csv')

# %%
df=df.toDF(*[i.lower().replace(' ','_')for i in df.columns])

# %%
display(df)
